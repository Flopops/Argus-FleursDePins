# %% [markdown]
# # Train for train.py

# %% [markdown]
# Jupyter Cell by cell from the train.py script

# %%
import logging
import datetime

import torchvision
from tqdm.notebook import tqdm
import numpy as np
from dataset import PinesDataset
from torch.utils.data import random_split
import torch
from torch.utils.tensorboard import SummaryWriter

import dataset
import models
from train import train_one_epoch, evaluate, load_hyperparameters

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# %%
hyp = load_hyperparameters("cfg/hyperparameters.json")

# %%
writer = SummaryWriter("../../runs/pines")

# %%
# device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Method 1 : Loading data from memory 
pines_dataset = PinesDataset("/mnt/sda1/1-Pins/DATASET/", scale=hyp.scale)
train_set, val_set, test_set = random_split(
    dataset=pines_dataset,
    lengths=[0.8, 0.1, 0.1],
    generator=torch.Generator().manual_seed(42),
)
# Out:
# INFO-20240306-10:55:33|775 images and targets loaded

# %% [markdown]
# ou choisir la méthode 2

# %%
# Method 2 : loading data from memory and save it as it will be loaded after instead of all dataset

dataset.save_train_val_test_sets(root="/mnt/sda1/1-Pins/DATASET/", scale=1, save_dir="../../datasets/")
# train_set = torch.load("../datasets/train_set.pt")
# val_set = torch.load("../datasets/val_set.pt")
# test_set = torch.load("../datasets/test_set.pt")
# Out:
# INFO-20240306-11:43:58|8452 images and targets loaded

# %% [markdown]
# Dataldoaders

# %%
dataloaders = dataset.DataLoaders(
    train=torch.utils.data.DataLoader(
        train_set, batch_size=hyp.batch_size, collate_fn=dataset.collate_fn
    ),
    validation=torch.utils.data.DataLoader(
        val_set, batch_size=hyp.batch_size, collate_fn=dataset.collate_fn
    ),
    test=torch.utils.data.DataLoader(
        test_set, batch_size=hyp.batch_size, collate_fn=dataset.collate_fn
    ),
)

# %%
# Example code for plotting images batch on tensorboard
example_images, example_targets = dataset.prepare_batch(next(iter(dataloaders.train)), device)

img_grid = torchvision.utils.make_grid(example_images)
writer.add_image('pines_images', img_grid)

# %%
model = models.get_fasterrcnn_mobilenet_v3().to(device)
#     weights_path="../pretrained-models/fasterrcnn-scale1-bs32-epochs100-weights.pth"
# ).to(device)
# Out:
# INFO-20240306-10:55:51|FasterRCNN loaded with no pretrained weights

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=hyp.learning_rate, momentum=0.9, weight_decay=0.0005)

# %% [markdown]
# Train the model

# %%
for epoch in range(hyp.num_epochs):
    train_metric_logger = train_one_epoch(model, optimizer, dataloaders.train, device, epoch, print_freq=1)
    evaluator, eval_metric_logger = evaluate(model, dataloaders.validation, device, epoch, print_freq=1)
    writer.add_scalars(
        'losses', 
        {
            'train_sum':train_metric_logger.loss_sum.avg,
            'train_box_reg':train_metric_logger.meters["loss_box_reg"].avg,
        }, 
        epoch
    )
    writer.add_scalar('mAP', np.mean(evaluator.coco_eval.eval['precision'][:,:,:,0,2]), epoch)

    # TODO: plot the mAP for evaluator
    # TODO: give metric loggers and evaluator to a tensorboard handler for plotting the metrics

    # Track best performance, and save the model's state
    # if avg_vloss < best_vloss:
    #     best_vloss = avg_vloss
    #     model_path = 'model_{}_{}'.format(timestamp, epoch_number)
    #     torch.save(model.state_dict(), model_path)


print("Finished Training")
torch.cuda.empty_cache()
# Out:
# Train: [1]	[ 1/60]	eta: 0:03:01	loss_classifier: 0.0828 (0.0828)	loss_box_reg: 0.2574 (0.2574)	loss_objectness: 0.0033 (0.0033)	loss_rpn_box_reg: 0.0026 (0.0026)	loss_sum: 0.3461 (0.3461)	time: 3.0249	data: 0.0019	max mem: 5756
# Train: [1]	[ 2/60]	eta: 0:01:50	loss_classifier: 0.0828 (0.0932)	loss_box_reg: 0.2574 (0.2857)	loss_objectness: 0.0033 (0.0043)	loss_rpn_box_reg: 0.0026 (0.0028)	loss_sum: 0.3461 (0.3860)	time: 1.8808	data: 0.0016	max mem: 5870
# Train: [1]	[ 3/60]	eta: 0:01:25	loss_classifier: 0.1035 (0.1044)	loss_box_reg: 0.2782 (0.2832)	loss_objectness: 0.0053 (0.0047)	loss_rpn_box_reg: 0.0029 (0.0032)	loss_sum: 0.4141 (0.3954)	time: 1.4721	data: 0.0014	max mem: 5870
# Train: [1]	[ 4/60]	eta: 0:01:13	loss_classifier: 0.1035 (0.1134)	loss_box_reg: 0.2782 (0.3047)	loss_objectness: 0.0053 (0.0053)	loss_rpn_box_reg: 0.0029 (0.0033)	loss_sum: 0.4141 (0.4267)	time: 1.2823	data: 0.0014	max mem: 5870
# Train: [1]	[ 5/60]	eta: 0:01:04	loss_classifier: 0.1044 (0.1116)	loss_box_reg: 0.2810 (0.3000)	loss_objectness: 0.0053 (0.0052)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.4141 (0.4199)	time: 1.1582	data: 0.0013	max mem: 5870
# Train: [1]	[ 6/60]	eta: 0:01:00	loss_classifier: 0.1035 (0.1091)	loss_box_reg: 0.2782 (0.2957)	loss_objectness: 0.0050 (0.0051)	loss_rpn_box_reg: 0.0029 (0.0033)	loss_sum: 0.3927 (0.4131)	time: 1.0970	data: 0.0013	max mem: 5870
# Train: [1]	[ 7/60]	eta: 0:00:56	loss_classifier: 0.1044 (0.1095)	loss_box_reg: 0.2782 (0.2907)	loss_objectness: 0.0050 (0.0048)	loss_rpn_box_reg: 0.0033 (0.0033)	loss_sum: 0.3927 (0.4083)	time: 1.0445	data: 0.0013	max mem: 5870
# Train: [1]	[ 8/60]	eta: 0:00:53	loss_classifier: 0.1044 (0.1089)	loss_box_reg: 0.2746 (0.2854)	loss_objectness: 0.0048 (0.0048)	loss_rpn_box_reg: 0.0029 (0.0032)	loss_sum: 0.3793 (0.4023)	time: 1.0006	data: 0.0014	max mem: 5870
# Train: [1]	[ 9/60]	eta: 0:00:50	loss_classifier: 0.1044 (0.1073)	loss_box_reg: 0.2746 (0.2817)	loss_objectness: 0.0048 (0.0046)	loss_rpn_box_reg: 0.0033 (0.0032)	loss_sum: 0.3793 (0.3968)	time: 0.9697	data: 0.0014	max mem: 5879
# Train: [1]	[10/60]	eta: 0:00:48	loss_classifier: 0.1035 (0.1048)	loss_box_reg: 0.2603 (0.2751)	loss_objectness: 0.0041 (0.0044)	loss_rpn_box_reg: 0.0029 (0.0032)	loss_sum: 0.3790 (0.3875)	time: 0.9466	data: 0.0014	max mem: 5879
# Train: [1]	[11/60]	eta: 0:00:46	loss_classifier: 0.1035 (0.1027)	loss_box_reg: 0.2603 (0.2717)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3790 (0.3818)	time: 0.9306	data: 0.0014	max mem: 5879
# Train: [1]	[12/60]	eta: 0:00:44	loss_classifier: 0.1013 (0.1026)	loss_box_reg: 0.2603 (0.2709)	loss_objectness: 0.0041 (0.0044)	loss_rpn_box_reg: 0.0029 (0.0032)	loss_sum: 0.3729 (0.3811)	time: 0.9111	data: 0.0014	max mem: 5879
# Train: [1]	[13/60]	eta: 0:00:43	loss_classifier: 0.1035 (0.1063)	loss_box_reg: 0.2628 (0.2745)	loss_objectness: 0.0048 (0.0045)	loss_rpn_box_reg: 0.0033 (0.0033)	loss_sum: 0.3790 (0.3886)	time: 0.8968	data: 0.0013	max mem: 5879
# Train: [1]	[14/60]	eta: 0:00:41	loss_classifier: 0.1035 (0.1082)	loss_box_reg: 0.2628 (0.2754)	loss_objectness: 0.0041 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0032)	loss_sum: 0.3790 (0.3914)	time: 0.8791	data: 0.0013	max mem: 5879
# Train: [1]	[15/60]	eta: 0:00:39	loss_classifier: 0.1044 (0.1081)	loss_box_reg: 0.2746 (0.2764)	loss_objectness: 0.0045 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0032)	loss_sum: 0.3793 (0.3921)	time: 0.8655	data: 0.0013	max mem: 5879
# Train: [1]	[16/60]	eta: 0:00:38	loss_classifier: 0.1035 (0.1076)	loss_box_reg: 0.2628 (0.2739)	loss_objectness: 0.0045 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0032)	loss_sum: 0.3790 (0.3893)	time: 0.8536	data: 0.0013	max mem: 5879
# Train: [1]	[17/60]	eta: 0:00:37	loss_classifier: 0.1044 (0.1088)	loss_box_reg: 0.2746 (0.2742)	loss_objectness: 0.0045 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0032)	loss_sum: 0.3793 (0.3907)	time: 0.8422	data: 0.0013	max mem: 5879
# Train: [1]	[18/60]	eta: 0:00:35	loss_classifier: 0.1035 (0.1065)	loss_box_reg: 0.2628 (0.2699)	loss_objectness: 0.0041 (0.0044)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3790 (0.3840)	time: 0.8315	data: 0.0013	max mem: 5879
# Train: [1]	[19/60]	eta: 0:00:34	loss_classifier: 0.1044 (0.1067)	loss_box_reg: 0.2745 (0.2702)	loss_objectness: 0.0044 (0.0044)	loss_rpn_box_reg: 0.0030 (0.0032)	loss_sum: 0.3793 (0.3844)	time: 0.8241	data: 0.0013	max mem: 5879
# Train: [1]	[20/60]	eta: 0:00:33	loss_classifier: 0.1035 (0.1057)	loss_box_reg: 0.2628 (0.2686)	loss_objectness: 0.0041 (0.0044)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3790 (0.3818)	time: 0.8165	data: 0.0013	max mem: 5879
# Train: [1]	[21/60]	eta: 0:00:32	loss_classifier: 0.1035 (0.1053)	loss_box_reg: 0.2745 (0.2690)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3793 (0.3817)	time: 0.6985	data: 0.0012	max mem: 5879
# Train: [1]	[22/60]	eta: 0:00:31	loss_classifier: 0.1013 (0.1050)	loss_box_reg: 0.2628 (0.2674)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3790 (0.3797)	time: 0.6961	data: 0.0012	max mem: 5879
# Train: [1]	[23/60]	eta: 0:00:30	loss_classifier: 0.1013 (0.1055)	loss_box_reg: 0.2603 (0.2667)	loss_objectness: 0.0041 (0.0044)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3776 (0.3796)	time: 0.6977	data: 0.0012	max mem: 5879
# Train: [1]	[24/60]	eta: 0:00:29	loss_classifier: 0.1013 (0.1063)	loss_box_reg: 0.2603 (0.2680)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3776 (0.3816)	time: 0.6960	data: 0.0012	max mem: 5879
# Train: [1]	[25/60]	eta: 0:00:28	loss_classifier: 0.1013 (0.1079)	loss_box_reg: 0.2603 (0.2693)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3776 (0.3845)	time: 0.6974	data: 0.0012	max mem: 5879
# Train: [1]	[26/60]	eta: 0:00:27	loss_classifier: 0.1044 (0.1083)	loss_box_reg: 0.2603 (0.2700)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3776 (0.3857)	time: 0.6919	data: 0.0012	max mem: 5879
# Train: [1]	[27/60]	eta: 0:00:26	loss_classifier: 0.1044 (0.1082)	loss_box_reg: 0.2628 (0.2701)	loss_objectness: 0.0041 (0.0044)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3776 (0.3858)	time: 0.6898	data: 0.0012	max mem: 5879
# Train: [1]	[28/60]	eta: 0:00:25	loss_classifier: 0.1013 (0.1077)	loss_box_reg: 0.2628 (0.2678)	loss_objectness: 0.0041 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0031)	loss_sum: 0.3776 (0.3830)	time: 0.6904	data: 0.0012	max mem: 5879
# Train: [1]	[29/60]	eta: 0:00:24	loss_classifier: 0.1056 (0.1080)	loss_box_reg: 0.2628 (0.2666)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3776 (0.3822)	time: 0.6905	data: 0.0012	max mem: 5879
# Train: [1]	[30/60]	eta: 0:00:24	loss_classifier: 0.1062 (0.1084)	loss_box_reg: 0.2726 (0.2679)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0031)	loss_sum: 0.3804 (0.3839)	time: 0.6886	data: 0.0012	max mem: 5879
# Train: [1]	[31/60]	eta: 0:00:23	loss_classifier: 0.1062 (0.1082)	loss_box_reg: 0.2745 (0.2684)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0031)	loss_sum: 0.3893 (0.3842)	time: 0.6874	data: 0.0012	max mem: 5879
# Train: [1]	[32/60]	eta: 0:00:22	loss_classifier: 0.1072 (0.1082)	loss_box_reg: 0.2745 (0.2682)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0031)	loss_sum: 0.3893 (0.3839)	time: 0.6910	data: 0.0012	max mem: 5879
# Train: [1]	[33/60]	eta: 0:00:21	loss_classifier: 0.1068 (0.1081)	loss_box_reg: 0.2726 (0.2677)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3804 (0.3835)	time: 0.6921	data: 0.0012	max mem: 5879
# Train: [1]	[34/60]	eta: 0:00:20	loss_classifier: 0.1062 (0.1075)	loss_box_reg: 0.2595 (0.2674)	loss_objectness: 0.0044 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3776 (0.3824)	time: 0.6962	data: 0.0012	max mem: 5879
# Train: [1]	[35/60]	eta: 0:00:20	loss_classifier: 0.1068 (0.1078)	loss_box_reg: 0.2595 (0.2679)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3776 (0.3833)	time: 0.6984	data: 0.0012	max mem: 5879
# Train: [1]	[36/60]	eta: 0:00:19	loss_classifier: 0.1068 (0.1077)	loss_box_reg: 0.2595 (0.2664)	loss_objectness: 0.0042 (0.0045)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3776 (0.3817)	time: 0.7022	data: 0.0012	max mem: 5879
# Train: [1]	[37/60]	eta: 0:00:18	loss_classifier: 0.1068 (0.1099)	loss_box_reg: 0.2595 (0.2702)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3776 (0.3877)	time: 0.7067	data: 0.0012	max mem: 5879
# Train: [1]	[38/60]	eta: 0:00:17	loss_classifier: 0.1068 (0.1094)	loss_box_reg: 0.2595 (0.2685)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0031)	loss_sum: 0.3776 (0.3855)	time: 0.7125	data: 0.0012	max mem: 5879
# Train: [1]	[39/60]	eta: 0:00:16	loss_classifier: 0.1068 (0.1110)	loss_box_reg: 0.2595 (0.2693)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0031)	loss_sum: 0.3776 (0.3878)	time: 0.7129	data: 0.0012	max mem: 5879
# Train: [1]	[40/60]	eta: 0:00:16	loss_classifier: 0.1068 (0.1106)	loss_box_reg: 0.2595 (0.2679)	loss_objectness: 0.0045 (0.0045)	loss_rpn_box_reg: 0.0031 (0.0032)	loss_sum: 0.3776 (0.3862)	time: 0.7177	data: 0.0012	max mem: 5879
# Train: [1]	[41/60]	eta: 0:00:15	loss_classifier: 0.1072 (0.1120)	loss_box_reg: 0.2595 (0.2708)	loss_objectness: 0.0045 (0.0045)	loss_rpn_box_reg: 0.0032 (0.0032)	loss_sum: 0.3776 (0.3905)	time: 0.7252	data: 0.0012	max mem: 5879
# Train: [1]	[42/60]	eta: 0:00:14	loss_classifier: 0.1166 (0.1122)	loss_box_reg: 0.2595 (0.2702)	loss_objectness: 0.0045 (0.0045)	loss_rpn_box_reg: 0.0032 (0.0032)	loss_sum: 0.3776 (0.3901)	time: 0.7255	data: 0.0012	max mem: 5879
# Train: [1]	[43/60]	eta: 0:00:13	loss_classifier: 0.1072 (0.1121)	loss_box_reg: 0.2595 (0.2699)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0031 (0.0032)	loss_sum: 0.3746 (0.3896)	time: 0.7292	data: 0.0012	max mem: 5879
# Train: [1]	[44/60]	eta: 0:00:13	loss_classifier: 0.1072 (0.1121)	loss_box_reg: 0.2595 (0.2697)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0031 (0.0031)	loss_sum: 0.3746 (0.3894)	time: 0.7340	data: 0.0012	max mem: 5879
# Train: [1]	[45/60]	eta: 0:00:12	loss_classifier: 0.1072 (0.1124)	loss_box_reg: 0.2590 (0.2689)	loss_objectness: 0.0045 (0.0045)	loss_rpn_box_reg: 0.0030 (0.0031)	loss_sum: 0.3741 (0.3889)	time: 0.7353	data: 0.0012	max mem: 5879
# Train: [1]	[46/60]	eta: 0:00:11	loss_classifier: 0.1072 (0.1125)	loss_box_reg: 0.2590 (0.2690)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0029 (0.0031)	loss_sum: 0.3741 (0.3891)	time: 0.7382	data: 0.0012	max mem: 5879
# Train: [1]	[47/60]	eta: 0:00:10	loss_classifier: 0.1072 (0.1119)	loss_box_reg: 0.2561 (0.2676)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0029 (0.0032)	loss_sum: 0.3708 (0.3872)	time: 0.7417	data: 0.0012	max mem: 5879
# Train: [1]	[48/60]	eta: 0:00:09	loss_classifier: 0.1072 (0.1110)	loss_box_reg: 0.2561 (0.2662)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3708 (0.3847)	time: 0.7441	data: 0.0012	max mem: 5879
# Train: [1]	[49/60]	eta: 0:00:09	loss_classifier: 0.1072 (0.1110)	loss_box_reg: 0.2561 (0.2657)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3708 (0.3842)	time: 0.7457	data: 0.0012	max mem: 5879
# Train: [1]	[50/60]	eta: 0:00:08	loss_classifier: 0.1068 (0.1107)	loss_box_reg: 0.2543 (0.2642)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3685 (0.3824)	time: 0.7460	data: 0.0012	max mem: 5879
# Train: [1]	[51/60]	eta: 0:00:07	loss_classifier: 0.1068 (0.1105)	loss_box_reg: 0.2543 (0.2642)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3685 (0.3822)	time: 0.7489	data: 0.0012	max mem: 5879
# Train: [1]	[52/60]	eta: 0:00:06	loss_classifier: 0.1068 (0.1108)	loss_box_reg: 0.2543 (0.2644)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3685 (0.3827)	time: 0.7456	data: 0.0012	max mem: 5879
# Train: [1]	[53/60]	eta: 0:00:06	loss_classifier: 0.1098 (0.1107)	loss_box_reg: 0.2561 (0.2654)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3708 (0.3837)	time: 0.7443	data: 0.0012	max mem: 5879
# Train: [1]	[54/60]	eta: 0:00:05	loss_classifier: 0.1104 (0.1108)	loss_box_reg: 0.2590 (0.2655)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3730 (0.3838)	time: 0.7438	data: 0.0012	max mem: 5879
# Train: [1]	[55/60]	eta: 0:00:04	loss_classifier: 0.1098 (0.1106)	loss_box_reg: 0.2590 (0.2659)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3730 (0.3841)	time: 0.7442	data: 0.0012	max mem: 5879
# Train: [1]	[56/60]	eta: 0:00:03	loss_classifier: 0.1104 (0.1116)	loss_box_reg: 0.2625 (0.2681)	loss_objectness: 0.0043 (0.0045)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3741 (0.3873)	time: 0.7463	data: 0.0012	max mem: 5903
# Train: [1]	[57/60]	eta: 0:00:03	loss_classifier: 0.1104 (0.1123)	loss_box_reg: 0.2625 (0.2688)	loss_objectness: 0.0043 (0.0045)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3741 (0.3887)	time: 0.7464	data: 0.0012	max mem: 5903
# Train: [1]	[58/60]	eta: 0:00:02	loss_classifier: 0.1117 (0.1126)	loss_box_reg: 0.2625 (0.2694)	loss_objectness: 0.0044 (0.0045)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3797 (0.3896)	time: 0.7483	data: 0.0012	max mem: 5903
# Train: [1]	[59/60]	eta: 0:00:01	loss_classifier: 0.1104 (0.1124)	loss_box_reg: 0.2625 (0.2695)	loss_objectness: 0.0043 (0.0045)	loss_rpn_box_reg: 0.0027 (0.0031)	loss_sum: 0.3780 (0.3894)	time: 0.7523	data: 0.0012	max mem: 5903
# Train: [1]	[60/60]	eta: 0:00:00	loss_classifier: 0.1117 (0.1125)	loss_box_reg: 0.2717 (0.2698)	loss_objectness: 0.0043 (0.0045)	loss_rpn_box_reg: 0.0026 (0.0031)	loss_sum: 0.3797 (0.3899)	time: 0.7340	data: 0.0012	max mem: 5903
# Train: [1] Total time: 0:00:45 (0.7568s / iteration)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Test: [1]	[1/8]	eta: 0:00:03	model_time: 0.3640 (0.3640)	evaluator_time: 0.0190 (0.0190)	time: 0.3943	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [1]	[2/8]	eta: 0:00:02	model_time: 0.3472 (0.3556)	evaluator_time: 0.0136 (0.0163)	time: 0.3836	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [1]	[3/8]	eta: 0:00:02	model_time: 0.3472 (0.3493)	evaluator_time: 0.0184 (0.0170)	time: 0.3776	data: 0.0010	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [1]	[4/8]	eta: 0:00:01	model_time: 0.3400 (0.3470)	evaluator_time: 0.0136 (0.0161)	time: 0.3743	data: 0.0010	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [1]	[5/8]	eta: 0:00:01	model_time: 0.3409 (0.3458)	evaluator_time: 0.0148 (0.0158)	time: 0.3729	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [1]	[6/8]	eta: 0:00:01	model_time: 0.3400 (0.3439)	evaluator_time: 0.0137 (0.0155)	time: 0.3705	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [1]	[7/8]	eta: 0:00:00	model_time: 0.3400 (0.3431)	evaluator_time: 0.0141 (0.0153)	time: 0.3693	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [1]	[8/8]	eta: 0:00:00	model_time: 0.3384 (0.3205)	evaluator_time: 0.0137 (0.0142)	time: 0.3450	data: 0.0008	max mem: 5903
# Test: [1] Total time: 0:00:02 (0.3454s / iteration)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.623
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.842
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.676
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.603
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.950
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Train: [2]	[ 1/60]	eta: 0:00:37	loss_classifier: 0.0869 (0.0869)	loss_box_reg: 0.1924 (0.1924)	loss_objectness: 0.0036 (0.0036)	loss_rpn_box_reg: 0.0023 (0.0023)	loss_sum: 0.2852 (0.2852)	time: 0.6255	data: 0.0014	max mem: 5903
# Train: [2]	[ 2/60]	eta: 0:00:37	loss_classifier: 0.0869 (0.1026)	loss_box_reg: 0.1924 (0.2354)	loss_objectness: 0.0036 (0.0042)	loss_rpn_box_reg: 0.0023 (0.0026)	loss_sum: 0.2852 (0.3447)	time: 0.6305	data: 0.0013	max mem: 5903
# Train: [2]	[ 3/60]	eta: 0:00:36	loss_classifier: 0.1182 (0.1102)	loss_box_reg: 0.2421 (0.2377)	loss_objectness: 0.0048 (0.0045)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3762 (0.3552)	time: 0.6251	data: 0.0012	max mem: 5903
# Train: [2]	[ 4/60]	eta: 0:00:35	loss_classifier: 0.1182 (0.1161)	loss_box_reg: 0.2421 (0.2512)	loss_objectness: 0.0048 (0.0050)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3762 (0.3754)	time: 0.6311	data: 0.0012	max mem: 5903
# Train: [2]	[ 5/60]	eta: 0:00:34	loss_classifier: 0.1182 (0.1135)	loss_box_reg: 0.2480 (0.2506)	loss_objectness: 0.0048 (0.0047)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3762 (0.3718)	time: 0.6240	data: 0.0012	max mem: 5903
# Train: [2]	[ 6/60]	eta: 0:00:34	loss_classifier: 0.1033 (0.1111)	loss_box_reg: 0.2421 (0.2487)	loss_objectness: 0.0036 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3572 (0.3672)	time: 0.6214	data: 0.0011	max mem: 5903
# Train: [2]	[ 7/60]	eta: 0:00:33	loss_classifier: 0.1033 (0.1078)	loss_box_reg: 0.2421 (0.2464)	loss_objectness: 0.0036 (0.0042)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3572 (0.3614)	time: 0.6178	data: 0.0011	max mem: 5903
# Train: [2]	[ 8/60]	eta: 0:00:32	loss_classifier: 0.1033 (0.1076)	loss_box_reg: 0.2391 (0.2436)	loss_objectness: 0.0036 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3443 (0.3584)	time: 0.6188	data: 0.0012	max mem: 5903
# Train: [2]	[ 9/60]	eta: 0:00:32	loss_classifier: 0.1033 (0.1058)	loss_box_reg: 0.2421 (0.2437)	loss_objectness: 0.0046 (0.0043)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3443 (0.3568)	time: 0.6198	data: 0.0011	max mem: 5903
# Train: [2]	[10/60]	eta: 0:00:31	loss_classifier: 0.0987 (0.1030)	loss_box_reg: 0.2391 (0.2378)	loss_objectness: 0.0036 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3443 (0.3479)	time: 0.6190	data: 0.0011	max mem: 5903
# Train: [2]	[11/60]	eta: 0:00:30	loss_classifier: 0.0987 (0.1013)	loss_box_reg: 0.2391 (0.2359)	loss_objectness: 0.0036 (0.0040)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3443 (0.3442)	time: 0.6190	data: 0.0011	max mem: 5903
# Train: [2]	[12/60]	eta: 0:00:30	loss_classifier: 0.0934 (0.1007)	loss_box_reg: 0.2391 (0.2371)	loss_objectness: 0.0036 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3443 (0.3449)	time: 0.6194	data: 0.0011	max mem: 5903
# Train: [2]	[13/60]	eta: 0:00:29	loss_classifier: 0.0987 (0.1029)	loss_box_reg: 0.2421 (0.2437)	loss_objectness: 0.0046 (0.0042)	loss_rpn_box_reg: 0.0031 (0.0031)	loss_sum: 0.3443 (0.3539)	time: 0.6182	data: 0.0011	max mem: 5903
# Train: [2]	[14/60]	eta: 0:00:29	loss_classifier: 0.0987 (0.1050)	loss_box_reg: 0.2421 (0.2464)	loss_objectness: 0.0046 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3443 (0.3587)	time: 0.6178	data: 0.0011	max mem: 5903
# Train: [2]	[15/60]	eta: 0:00:28	loss_classifier: 0.1019 (0.1048)	loss_box_reg: 0.2445 (0.2488)	loss_objectness: 0.0046 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3519 (0.3609)	time: 0.6165	data: 0.0011	max mem: 5903
# Train: [2]	[16/60]	eta: 0:00:27	loss_classifier: 0.1019 (0.1048)	loss_box_reg: 0.2421 (0.2467)	loss_objectness: 0.0046 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3443 (0.3588)	time: 0.6172	data: 0.0011	max mem: 5903
# Train: [2]	[17/60]	eta: 0:00:27	loss_classifier: 0.1033 (0.1064)	loss_box_reg: 0.2445 (0.2476)	loss_objectness: 0.0046 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3519 (0.3613)	time: 0.6160	data: 0.0011	max mem: 5903
# Train: [2]	[18/60]	eta: 0:00:26	loss_classifier: 0.1019 (0.1045)	loss_box_reg: 0.2421 (0.2452)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3443 (0.3568)	time: 0.6152	data: 0.0011	max mem: 5903
# Train: [2]	[19/60]	eta: 0:00:25	loss_classifier: 0.1033 (0.1045)	loss_box_reg: 0.2445 (0.2456)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3519 (0.3572)	time: 0.6153	data: 0.0011	max mem: 5903
# Train: [2]	[20/60]	eta: 0:00:25	loss_classifier: 0.1019 (0.1037)	loss_box_reg: 0.2421 (0.2443)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3443 (0.3550)	time: 0.6147	data: 0.0011	max mem: 5903
# Train: [2]	[21/60]	eta: 0:00:24	loss_classifier: 0.1019 (0.1033)	loss_box_reg: 0.2445 (0.2449)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3519 (0.3551)	time: 0.6140	data: 0.0011	max mem: 5903
# Train: [2]	[22/60]	eta: 0:00:24	loss_classifier: 0.0987 (0.1028)	loss_box_reg: 0.2421 (0.2440)	loss_objectness: 0.0037 (0.0040)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3443 (0.3536)	time: 0.6155	data: 0.0011	max mem: 5903
# Train: [2]	[23/60]	eta: 0:00:23	loss_classifier: 0.0987 (0.1028)	loss_box_reg: 0.2391 (0.2434)	loss_objectness: 0.0037 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3443 (0.3531)	time: 0.6160	data: 0.0011	max mem: 5903
# Train: [2]	[24/60]	eta: 0:00:22	loss_classifier: 0.0987 (0.1035)	loss_box_reg: 0.2391 (0.2453)	loss_objectness: 0.0036 (0.0040)	loss_rpn_box_reg: 0.0026 (0.0029)	loss_sum: 0.3443 (0.3557)	time: 0.6139	data: 0.0011	max mem: 5903
# Train: [2]	[25/60]	eta: 0:00:22	loss_classifier: 0.0987 (0.1045)	loss_box_reg: 0.2391 (0.2469)	loss_objectness: 0.0037 (0.0040)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3443 (0.3583)	time: 0.6175	data: 0.0012	max mem: 5903
# Train: [2]	[26/60]	eta: 0:00:21	loss_classifier: 0.1019 (0.1049)	loss_box_reg: 0.2445 (0.2480)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3443 (0.3598)	time: 0.6210	data: 0.0012	max mem: 5903
# Train: [2]	[27/60]	eta: 0:00:21	loss_classifier: 0.1031 (0.1050)	loss_box_reg: 0.2500 (0.2484)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3519 (0.3605)	time: 0.6265	data: 0.0012	max mem: 5903
# Train: [2]	[28/60]	eta: 0:00:20	loss_classifier: 0.1019 (0.1046)	loss_box_reg: 0.2500 (0.2462)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3519 (0.3578)	time: 0.6302	data: 0.0012	max mem: 5903
# Train: [2]	[29/60]	eta: 0:00:20	loss_classifier: 0.1024 (0.1045)	loss_box_reg: 0.2500 (0.2449)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3519 (0.3564)	time: 0.6288	data: 0.0012	max mem: 5903
# Train: [2]	[30/60]	eta: 0:00:19	loss_classifier: 0.1031 (0.1049)	loss_box_reg: 0.2531 (0.2463)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3571 (0.3582)	time: 0.6317	data: 0.0012	max mem: 5903
# Train: [2]	[31/60]	eta: 0:00:18	loss_classifier: 0.1031 (0.1044)	loss_box_reg: 0.2570 (0.2474)	loss_objectness: 0.0040 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3645 (0.3588)	time: 0.6326	data: 0.0012	max mem: 5903
# Train: [2]	[32/60]	eta: 0:00:18	loss_classifier: 0.1044 (0.1045)	loss_box_reg: 0.2570 (0.2474)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3645 (0.3590)	time: 0.6323	data: 0.0012	max mem: 5903
# Train: [2]	[33/60]	eta: 0:00:17	loss_classifier: 0.1044 (0.1045)	loss_box_reg: 0.2531 (0.2473)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3635 (0.3589)	time: 0.6376	data: 0.0012	max mem: 5903
# Train: [2]	[34/60]	eta: 0:00:17	loss_classifier: 0.1031 (0.1040)	loss_box_reg: 0.2487 (0.2471)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3571 (0.3581)	time: 0.6416	data: 0.0012	max mem: 5903
# Train: [2]	[35/60]	eta: 0:00:16	loss_classifier: 0.1031 (0.1037)	loss_box_reg: 0.2487 (0.2475)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3571 (0.3584)	time: 0.6432	data: 0.0012	max mem: 5903
# Train: [2]	[36/60]	eta: 0:00:15	loss_classifier: 0.1024 (0.1035)	loss_box_reg: 0.2487 (0.2465)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3571 (0.3571)	time: 0.6461	data: 0.0012	max mem: 5903
# Train: [2]	[37/60]	eta: 0:00:15	loss_classifier: 0.1024 (0.1055)	loss_box_reg: 0.2487 (0.2506)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3571 (0.3633)	time: 0.6479	data: 0.0012	max mem: 5903
# Train: [2]	[38/60]	eta: 0:00:14	loss_classifier: 0.1024 (0.1050)	loss_box_reg: 0.2487 (0.2492)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3571 (0.3615)	time: 0.6499	data: 0.0012	max mem: 5903
# Train: [2]	[39/60]	eta: 0:00:13	loss_classifier: 0.1024 (0.1063)	loss_box_reg: 0.2487 (0.2504)	loss_objectness: 0.0040 (0.0042)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3571 (0.3640)	time: 0.6498	data: 0.0013	max mem: 5903
# Train: [2]	[40/60]	eta: 0:00:13	loss_classifier: 0.1024 (0.1060)	loss_box_reg: 0.2487 (0.2492)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0031 (0.0031)	loss_sum: 0.3571 (0.3624)	time: 0.6513	data: 0.0013	max mem: 5903
# Train: [2]	[41/60]	eta: 0:00:12	loss_classifier: 0.1031 (0.1071)	loss_box_reg: 0.2487 (0.2521)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0032 (0.0031)	loss_sum: 0.3635 (0.3665)	time: 0.6552	data: 0.0013	max mem: 5903
# Train: [2]	[42/60]	eta: 0:00:12	loss_classifier: 0.1065 (0.1073)	loss_box_reg: 0.2487 (0.2515)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0032 (0.0031)	loss_sum: 0.3635 (0.3661)	time: 0.6528	data: 0.0013	max mem: 5903
# Train: [2]	[43/60]	eta: 0:00:11	loss_classifier: 0.1065 (0.1073)	loss_box_reg: 0.2540 (0.2515)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0031 (0.0031)	loss_sum: 0.3638 (0.3660)	time: 0.6526	data: 0.0013	max mem: 5903
# Train: [2]	[44/60]	eta: 0:00:10	loss_classifier: 0.1060 (0.1072)	loss_box_reg: 0.2540 (0.2516)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3638 (0.3661)	time: 0.6524	data: 0.0013	max mem: 5903
# Train: [2]	[45/60]	eta: 0:00:10	loss_classifier: 0.1060 (0.1074)	loss_box_reg: 0.2487 (0.2510)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3635 (0.3656)	time: 0.6494	data: 0.0013	max mem: 5903
# Train: [2]	[46/60]	eta: 0:00:09	loss_classifier: 0.1039 (0.1072)	loss_box_reg: 0.2487 (0.2512)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3635 (0.3656)	time: 0.6460	data: 0.0013	max mem: 5903
# Train: [2]	[47/60]	eta: 0:00:08	loss_classifier: 0.1024 (0.1067)	loss_box_reg: 0.2429 (0.2501)	loss_objectness: 0.0043 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3568 (0.3640)	time: 0.6415	data: 0.0013	max mem: 5903
# Train: [2]	[48/60]	eta: 0:00:08	loss_classifier: 0.1024 (0.1060)	loss_box_reg: 0.2429 (0.2488)	loss_objectness: 0.0043 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3568 (0.3620)	time: 0.6401	data: 0.0013	max mem: 5903
# Train: [2]	[49/60]	eta: 0:00:07	loss_classifier: 0.1037 (0.1059)	loss_box_reg: 0.2429 (0.2485)	loss_objectness: 0.0043 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3568 (0.3616)	time: 0.6444	data: 0.0013	max mem: 5903
# Train: [2]	[50/60]	eta: 0:00:06	loss_classifier: 0.1011 (0.1056)	loss_box_reg: 0.2400 (0.2473)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3495 (0.3601)	time: 0.6476	data: 0.0013	max mem: 5903
# Train: [2]	[51/60]	eta: 0:00:06	loss_classifier: 0.1011 (0.1055)	loss_box_reg: 0.2400 (0.2476)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3495 (0.3602)	time: 0.6533	data: 0.0014	max mem: 5903
# Train: [2]	[52/60]	eta: 0:00:05	loss_classifier: 0.1011 (0.1056)	loss_box_reg: 0.2400 (0.2481)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3495 (0.3609)	time: 0.6558	data: 0.0014	max mem: 5903
# Train: [2]	[53/60]	eta: 0:00:05	loss_classifier: 0.1011 (0.1057)	loss_box_reg: 0.2400 (0.2490)	loss_objectness: 0.0040 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3495 (0.3619)	time: 0.6534	data: 0.0014	max mem: 5903
# Train: [2]	[54/60]	eta: 0:00:04	loss_classifier: 0.1037 (0.1058)	loss_box_reg: 0.2480 (0.2490)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3638 (0.3620)	time: 0.6508	data: 0.0014	max mem: 5903
# Train: [2]	[55/60]	eta: 0:00:03	loss_classifier: 0.1037 (0.1057)	loss_box_reg: 0.2480 (0.2495)	loss_objectness: 0.0040 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3638 (0.3623)	time: 0.6493	data: 0.0014	max mem: 5903
# Train: [2]	[56/60]	eta: 0:00:03	loss_classifier: 0.1039 (0.1066)	loss_box_reg: 0.2540 (0.2519)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3643 (0.3656)	time: 0.6469	data: 0.0013	max mem: 5903
# Train: [2]	[57/60]	eta: 0:00:02	loss_classifier: 0.1039 (0.1072)	loss_box_reg: 0.2540 (0.2529)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3643 (0.3674)	time: 0.6458	data: 0.0013	max mem: 5903
# Train: [2]	[58/60]	eta: 0:00:01	loss_classifier: 0.1060 (0.1076)	loss_box_reg: 0.2563 (0.2536)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0031)	loss_sum: 0.3674 (0.3684)	time: 0.6449	data: 0.0013	max mem: 5903
# Train: [2]	[59/60]	eta: 0:00:01	loss_classifier: 0.1039 (0.1073)	loss_box_reg: 0.2563 (0.2538)	loss_objectness: 0.0040 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3674 (0.3684)	time: 0.6447	data: 0.0013	max mem: 5903
# Train: [2]	[60/60]	eta: 0:00:00	loss_classifier: 0.1060 (0.1075)	loss_box_reg: 0.2601 (0.2540)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0026 (0.0030)	loss_sum: 0.3674 (0.3686)	time: 0.6289	data: 0.0012	max mem: 5903
# Train: [2] Total time: 0:00:37 (0.6323s / iteration)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [2]	[1/8]	eta: 0:00:02	model_time: 0.3401 (0.3401)	evaluator_time: 0.0129 (0.0129)	time: 0.3620	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [2]	[2/8]	eta: 0:00:02	model_time: 0.3351 (0.3376)	evaluator_time: 0.0127 (0.0128)	time: 0.3591	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [2]	[3/8]	eta: 0:00:02	model_time: 0.3351 (0.3345)	evaluator_time: 0.0129 (0.0137)	time: 0.3568	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [2]	[4/8]	eta: 0:00:01	model_time: 0.3351 (0.3350)	evaluator_time: 0.0129 (0.0135)	time: 0.3571	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [2]	[5/8]	eta: 0:00:01	model_time: 0.3364 (0.3370)	evaluator_time: 0.0131 (0.0137)	time: 0.3592	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [2]	[6/8]	eta: 0:00:01	model_time: 0.3351 (0.3352)	evaluator_time: 0.0129 (0.0135)	time: 0.3573	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [2]	[7/8]	eta: 0:00:00	model_time: 0.3364 (0.3364)	evaluator_time: 0.0129 (0.0134)	time: 0.3585	data: 0.0009	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.00s).
# Test: [2]	[8/8]	eta: 0:00:00	model_time: 0.3351 (0.3135)	evaluator_time: 0.0128 (0.0125)	time: 0.3340	data: 0.0008	max mem: 5903
# Test: [2] Total time: 0:00:02 (0.3343s / iteration)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.842
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.673
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.607
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.925
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.303
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.661
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.950
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Train: [3]	[ 1/60]	eta: 0:00:37	loss_classifier: 0.0840 (0.0840)	loss_box_reg: 0.1916 (0.1916)	loss_objectness: 0.0033 (0.0033)	loss_rpn_box_reg: 0.0023 (0.0023)	loss_sum: 0.2812 (0.2812)	time: 0.6249	data: 0.0012	max mem: 5903
# Train: [3]	[ 2/60]	eta: 0:00:38	loss_classifier: 0.0840 (0.0990)	loss_box_reg: 0.1916 (0.2304)	loss_objectness: 0.0033 (0.0037)	loss_rpn_box_reg: 0.0023 (0.0025)	loss_sum: 0.2812 (0.3356)	time: 0.6480	data: 0.0012	max mem: 5903
# Train: [3]	[ 3/60]	eta: 0:00:36	loss_classifier: 0.1139 (0.1060)	loss_box_reg: 0.2318 (0.2308)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3611 (0.3441)	time: 0.6329	data: 0.0012	max mem: 5903
# Train: [3]	[ 4/60]	eta: 0:00:36	loss_classifier: 0.1139 (0.1134)	loss_box_reg: 0.2318 (0.2451)	loss_objectness: 0.0041 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3611 (0.3660)	time: 0.6414	data: 0.0012	max mem: 5903
# Train: [3]	[ 5/60]	eta: 0:00:35	loss_classifier: 0.1139 (0.1097)	loss_box_reg: 0.2498 (0.2460)	loss_objectness: 0.0046 (0.0045)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3611 (0.3631)	time: 0.6393	data: 0.0012	max mem: 5903
# Train: [3]	[ 6/60]	eta: 0:00:35	loss_classifier: 0.0949 (0.1069)	loss_box_reg: 0.2325 (0.2438)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3516 (0.3580)	time: 0.6377	data: 0.0012	max mem: 5903
# Train: [3]	[ 7/60]	eta: 0:00:34	loss_classifier: 0.0949 (0.1039)	loss_box_reg: 0.2334 (0.2423)	loss_objectness: 0.0041 (0.0040)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3516 (0.3533)	time: 0.6331	data: 0.0012	max mem: 5903
# Train: [3]	[ 8/60]	eta: 0:00:33	loss_classifier: 0.0949 (0.1037)	loss_box_reg: 0.2325 (0.2395)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3327 (0.3503)	time: 0.6321	data: 0.0012	max mem: 5903
# Train: [3]	[ 9/60]	eta: 0:00:33	loss_classifier: 0.0979 (0.1030)	loss_box_reg: 0.2334 (0.2394)	loss_objectness: 0.0046 (0.0042)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3449 (0.3497)	time: 0.6352	data: 0.0012	max mem: 5903
# Train: [3]	[10/60]	eta: 0:00:32	loss_classifier: 0.0949 (0.1004)	loss_box_reg: 0.2325 (0.2337)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3327 (0.3411)	time: 0.6417	data: 0.0012	max mem: 5903
# Train: [3]	[11/60]	eta: 0:00:32	loss_classifier: 0.0949 (0.0990)	loss_box_reg: 0.2325 (0.2324)	loss_objectness: 0.0046 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3327 (0.3385)	time: 0.6470	data: 0.0012	max mem: 5903
# Train: [3]	[12/60]	eta: 0:00:31	loss_classifier: 0.0929 (0.0983)	loss_box_reg: 0.2325 (0.2338)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3327 (0.3392)	time: 0.6473	data: 0.0012	max mem: 5903
# Train: [3]	[13/60]	eta: 0:00:31	loss_classifier: 0.0949 (0.1003)	loss_box_reg: 0.2334 (0.2404)	loss_objectness: 0.0046 (0.0043)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3449 (0.3480)	time: 0.6463	data: 0.0012	max mem: 5903
# Train: [3]	[14/60]	eta: 0:00:30	loss_classifier: 0.0949 (0.1021)	loss_box_reg: 0.2334 (0.2432)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3449 (0.3527)	time: 0.6444	data: 0.0013	max mem: 5903
# Train: [3]	[15/60]	eta: 0:00:29	loss_classifier: 0.0973 (0.1018)	loss_box_reg: 0.2388 (0.2454)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3469 (0.3545)	time: 0.6421	data: 0.0013	max mem: 5903
# Train: [3]	[16/60]	eta: 0:00:28	loss_classifier: 0.0973 (0.1015)	loss_box_reg: 0.2334 (0.2433)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3449 (0.3521)	time: 0.6412	data: 0.0013	max mem: 5903
# Train: [3]	[17/60]	eta: 0:00:28	loss_classifier: 0.0975 (0.1030)	loss_box_reg: 0.2388 (0.2440)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3469 (0.3543)	time: 0.6407	data: 0.0013	max mem: 5903
# Train: [3]	[18/60]	eta: 0:00:27	loss_classifier: 0.0973 (0.1010)	loss_box_reg: 0.2334 (0.2414)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3449 (0.3496)	time: 0.6402	data: 0.0013	max mem: 5903
# Train: [3]	[19/60]	eta: 0:00:26	loss_classifier: 0.0975 (0.1014)	loss_box_reg: 0.2388 (0.2420)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3469 (0.3505)	time: 0.6402	data: 0.0013	max mem: 5903
# Train: [3]	[20/60]	eta: 0:00:26	loss_classifier: 0.0973 (0.1007)	loss_box_reg: 0.2334 (0.2404)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3449 (0.3482)	time: 0.6386	data: 0.0013	max mem: 5903
# Train: [3]	[21/60]	eta: 0:00:25	loss_classifier: 0.0973 (0.1001)	loss_box_reg: 0.2388 (0.2408)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3449 (0.3479)	time: 0.6423	data: 0.0013	max mem: 5903
# Train: [3]	[22/60]	eta: 0:00:25	loss_classifier: 0.0949 (0.0996)	loss_box_reg: 0.2334 (0.2397)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0028)	loss_sum: 0.3427 (0.3463)	time: 0.6425	data: 0.0013	max mem: 5903
# Train: [3]	[23/60]	eta: 0:00:24	loss_classifier: 0.0949 (0.1000)	loss_box_reg: 0.2334 (0.2392)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3427 (0.3462)	time: 0.6434	data: 0.0013	max mem: 5903
# Train: [3]	[24/60]	eta: 0:00:23	loss_classifier: 0.0949 (0.1004)	loss_box_reg: 0.2334 (0.2410)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0026 (0.0029)	loss_sum: 0.3427 (0.3484)	time: 0.6402	data: 0.0013	max mem: 5903
# Train: [3]	[25/60]	eta: 0:00:23	loss_classifier: 0.0973 (0.1014)	loss_box_reg: 0.2334 (0.2427)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3427 (0.3510)	time: 0.6421	data: 0.0013	max mem: 5903
# Train: [3]	[26/60]	eta: 0:00:22	loss_classifier: 0.0975 (0.1017)	loss_box_reg: 0.2388 (0.2435)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3429 (0.3522)	time: 0.6438	data: 0.0013	max mem: 5903
# Train: [3]	[27/60]	eta: 0:00:21	loss_classifier: 0.0979 (0.1017)	loss_box_reg: 0.2483 (0.2440)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3449 (0.3530)	time: 0.6446	data: 0.0013	max mem: 5903
# Train: [3]	[28/60]	eta: 0:00:21	loss_classifier: 0.0975 (0.1014)	loss_box_reg: 0.2483 (0.2417)	loss_objectness: 0.0039 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3449 (0.3503)	time: 0.6446	data: 0.0013	max mem: 5903
# Train: [3]	[29/60]	eta: 0:00:20	loss_classifier: 0.0975 (0.1013)	loss_box_reg: 0.2483 (0.2405)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3429 (0.3490)	time: 0.6423	data: 0.0013	max mem: 5903
# Train: [3]	[30/60]	eta: 0:00:19	loss_classifier: 0.0991 (0.1016)	loss_box_reg: 0.2484 (0.2415)	loss_objectness: 0.0039 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3469 (0.3504)	time: 0.6388	data: 0.0013	max mem: 5903
# Train: [3]	[31/60]	eta: 0:00:19	loss_classifier: 0.0991 (0.1010)	loss_box_reg: 0.2525 (0.2423)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3561 (0.3505)	time: 0.6400	data: 0.0014	max mem: 5903
# Train: [3]	[32/60]	eta: 0:00:18	loss_classifier: 0.1033 (0.1011)	loss_box_reg: 0.2525 (0.2422)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3561 (0.3505)	time: 0.6380	data: 0.0014	max mem: 5903
# Train: [3]	[33/60]	eta: 0:00:17	loss_classifier: 0.1033 (0.1013)	loss_box_reg: 0.2483 (0.2421)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3516 (0.3505)	time: 0.6391	data: 0.0013	max mem: 5903
# Train: [3]	[34/60]	eta: 0:00:17	loss_classifier: 0.0991 (0.1007)	loss_box_reg: 0.2390 (0.2420)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3488 (0.3499)	time: 0.6407	data: 0.0013	max mem: 5903
# Train: [3]	[35/60]	eta: 0:00:16	loss_classifier: 0.0991 (0.1006)	loss_box_reg: 0.2390 (0.2422)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3488 (0.3501)	time: 0.6419	data: 0.0012	max mem: 5903
# Train: [3]	[36/60]	eta: 0:00:16	loss_classifier: 0.0991 (0.1003)	loss_box_reg: 0.2390 (0.2410)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3488 (0.3486)	time: 0.6418	data: 0.0012	max mem: 5903
# Train: [3]	[37/60]	eta: 0:00:15	loss_classifier: 0.0991 (0.1024)	loss_box_reg: 0.2390 (0.2449)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3488 (0.3546)	time: 0.6433	data: 0.0012	max mem: 5903
# Train: [3]	[38/60]	eta: 0:00:14	loss_classifier: 0.0991 (0.1021)	loss_box_reg: 0.2390 (0.2437)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3488 (0.3530)	time: 0.6438	data: 0.0012	max mem: 5903
# Train: [3]	[39/60]	eta: 0:00:14	loss_classifier: 0.0991 (0.1031)	loss_box_reg: 0.2390 (0.2451)	loss_objectness: 0.0039 (0.0042)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3488 (0.3554)	time: 0.6420	data: 0.0012	max mem: 5903
# Train: [3]	[40/60]	eta: 0:00:13	loss_classifier: 0.0991 (0.1028)	loss_box_reg: 0.2390 (0.2439)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0030 (0.0030)	loss_sum: 0.3488 (0.3540)	time: 0.6426	data: 0.0012	max mem: 5903
# Train: [3]	[41/60]	eta: 0:00:12	loss_classifier: 0.1033 (0.1038)	loss_box_reg: 0.2390 (0.2466)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0032 (0.0030)	loss_sum: 0.3516 (0.3577)	time: 0.6388	data: 0.0012	max mem: 5903
# Train: [3]	[42/60]	eta: 0:00:12	loss_classifier: 0.1034 (0.1040)	loss_box_reg: 0.2390 (0.2458)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0032 (0.0030)	loss_sum: 0.3516 (0.3571)	time: 0.6364	data: 0.0012	max mem: 5903
# Train: [3]	[43/60]	eta: 0:00:11	loss_classifier: 0.1033 (0.1038)	loss_box_reg: 0.2468 (0.2459)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0030 (0.0030)	loss_sum: 0.3516 (0.3570)	time: 0.6365	data: 0.0012	max mem: 5903
# Train: [3]	[44/60]	eta: 0:00:10	loss_classifier: 0.1033 (0.1038)	loss_box_reg: 0.2468 (0.2461)	loss_objectness: 0.0043 (0.0043)	loss_rpn_box_reg: 0.0030 (0.0030)	loss_sum: 0.3516 (0.3572)	time: 0.6367	data: 0.0012	max mem: 5903
# Train: [3]	[45/60]	eta: 0:00:10	loss_classifier: 0.1033 (0.1038)	loss_box_reg: 0.2390 (0.2454)	loss_objectness: 0.0043 (0.0043)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3513 (0.3565)	time: 0.6373	data: 0.0012	max mem: 5903
# Train: [3]	[46/60]	eta: 0:00:09	loss_classifier: 0.0991 (0.1037)	loss_box_reg: 0.2390 (0.2455)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3513 (0.3565)	time: 0.6386	data: 0.0012	max mem: 5903
# Train: [3]	[47/60]	eta: 0:00:08	loss_classifier: 0.0978 (0.1033)	loss_box_reg: 0.2377 (0.2444)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3488 (0.3551)	time: 0.6441	data: 0.0012	max mem: 5903
# Train: [3]	[48/60]	eta: 0:00:08	loss_classifier: 0.0978 (0.1026)	loss_box_reg: 0.2377 (0.2433)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3488 (0.3532)	time: 0.6471	data: 0.0012	max mem: 5903
# Train: [3]	[49/60]	eta: 0:00:07	loss_classifier: 0.0978 (0.1027)	loss_box_reg: 0.2377 (0.2428)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3488 (0.3528)	time: 0.6511	data: 0.0012	max mem: 5903
# Train: [3]	[50/60]	eta: 0:00:07	loss_classifier: 0.0972 (0.1024)	loss_box_reg: 0.2376 (0.2417)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3351 (0.3514)	time: 0.6508	data: 0.0012	max mem: 5903
# Train: [3]	[51/60]	eta: 0:00:06	loss_classifier: 0.0978 (0.1024)	loss_box_reg: 0.2376 (0.2422)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3351 (0.3519)	time: 0.6459	data: 0.0012	max mem: 5903
# Train: [3]	[52/60]	eta: 0:00:05	loss_classifier: 0.0978 (0.1027)	loss_box_reg: 0.2376 (0.2425)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3351 (0.3525)	time: 0.6462	data: 0.0012	max mem: 5903
# Train: [3]	[53/60]	eta: 0:00:05	loss_classifier: 0.0978 (0.1028)	loss_box_reg: 0.2390 (0.2434)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3351 (0.3536)	time: 0.6447	data: 0.0012	max mem: 5903
# Train: [3]	[54/60]	eta: 0:00:04	loss_classifier: 0.1022 (0.1029)	loss_box_reg: 0.2467 (0.2435)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3513 (0.3537)	time: 0.6426	data: 0.0012	max mem: 5903
# Train: [3]	[55/60]	eta: 0:00:03	loss_classifier: 0.1028 (0.1029)	loss_box_reg: 0.2467 (0.2439)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3513 (0.3541)	time: 0.6422	data: 0.0012	max mem: 5903
# Train: [3]	[56/60]	eta: 0:00:03	loss_classifier: 0.1037 (0.1037)	loss_box_reg: 0.2468 (0.2465)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3527 (0.3575)	time: 0.6427	data: 0.0012	max mem: 5903
# Train: [3]	[57/60]	eta: 0:00:02	loss_classifier: 0.1037 (0.1043)	loss_box_reg: 0.2468 (0.2476)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3527 (0.3592)	time: 0.6449	data: 0.0012	max mem: 5903
# Train: [3]	[58/60]	eta: 0:00:01	loss_classifier: 0.1037 (0.1046)	loss_box_reg: 0.2486 (0.2483)	loss_objectness: 0.0044 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3600 (0.3603)	time: 0.6446	data: 0.0012	max mem: 5903
# Train: [3]	[59/60]	eta: 0:00:01	loss_classifier: 0.1037 (0.1044)	loss_box_reg: 0.2486 (0.2486)	loss_objectness: 0.0044 (0.0044)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3600 (0.3604)	time: 0.6443	data: 0.0012	max mem: 5903
# ...
# Train: [5]	[ 7/60]	eta: 0:00:32	loss_classifier: 0.0961 (0.0997)	loss_box_reg: 0.2273 (0.2366)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0030 (0.0030)	loss_sum: 0.3409 (0.3437)	time: 0.6094	data: 0.0012	max mem: 5903
# Train: [5]	[ 8/60]	eta: 0:00:32	loss_classifier: 0.0961 (0.1003)	loss_box_reg: 0.2217 (0.2328)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3174 (0.3404)	time: 0.6097	data: 0.0012	max mem: 5903
# Train: [5]	[ 9/60]	eta: 0:00:31	loss_classifier: 0.0968 (0.0999)	loss_box_reg: 0.2273 (0.2339)	loss_objectness: 0.0043 (0.0044)	loss_rpn_box_reg: 0.0030 (0.0030)	loss_sum: 0.3409 (0.3412)	time: 0.6100	data: 0.0012	max mem: 5903
# Train: [5]	[10/60]	eta: 0:00:31	loss_classifier: 0.0961 (0.0973)	loss_box_reg: 0.2217 (0.2283)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3174 (0.3329)	time: 0.6104	data: 0.0012	max mem: 5903
# Train: [5]	[11/60]	eta: 0:00:30	loss_classifier: 0.0961 (0.0962)	loss_box_reg: 0.2217 (0.2269)	loss_objectness: 0.0042 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3174 (0.3303)	time: 0.6105	data: 0.0012	max mem: 5903
# Train: [5]	[12/60]	eta: 0:00:29	loss_classifier: 0.0876 (0.0955)	loss_box_reg: 0.2217 (0.2283)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3174 (0.3310)	time: 0.6104	data: 0.0012	max mem: 5903
# Train: [5]	[13/60]	eta: 0:00:29	loss_classifier: 0.0961 (0.0970)	loss_box_reg: 0.2273 (0.2347)	loss_objectness: 0.0042 (0.0044)	loss_rpn_box_reg: 0.0030 (0.0030)	loss_sum: 0.3383 (0.3391)	time: 0.6108	data: 0.0012	max mem: 5903
# Train: [5]	[14/60]	eta: 0:00:28	loss_classifier: 0.0961 (0.0986)	loss_box_reg: 0.2273 (0.2374)	loss_objectness: 0.0041 (0.0043)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3383 (0.3433)	time: 0.6112	data: 0.0012	max mem: 5903
# Train: [5]	[15/60]	eta: 0:00:28	loss_classifier: 0.0961 (0.0978)	loss_box_reg: 0.2426 (0.2398)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3409 (0.3448)	time: 0.6115	data: 0.0012	max mem: 5903
# Train: [5]	[16/60]	eta: 0:00:27	loss_classifier: 0.0905 (0.0974)	loss_box_reg: 0.2273 (0.2378)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3383 (0.3424)	time: 0.6107	data: 0.0012	max mem: 5903
# Train: [5]	[17/60]	eta: 0:00:26	loss_classifier: 0.0961 (0.0989)	loss_box_reg: 0.2426 (0.2386)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3409 (0.3446)	time: 0.6104	data: 0.0012	max mem: 5903
# Train: [5]	[18/60]	eta: 0:00:26	loss_classifier: 0.0905 (0.0971)	loss_box_reg: 0.2273 (0.2362)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3383 (0.3402)	time: 0.6095	data: 0.0012	max mem: 5903
# Train: [5]	[19/60]	eta: 0:00:25	loss_classifier: 0.0961 (0.0972)	loss_box_reg: 0.2426 (0.2367)	loss_objectness: 0.0041 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3409 (0.3410)	time: 0.6103	data: 0.0012	max mem: 5903
# Train: [5]	[20/60]	eta: 0:00:25	loss_classifier: 0.0905 (0.0966)	loss_box_reg: 0.2273 (0.2350)	loss_objectness: 0.0039 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3383 (0.3386)	time: 0.6128	data: 0.0012	max mem: 5903
# Train: [5]	[21/60]	eta: 0:00:24	loss_classifier: 0.0905 (0.0961)	loss_box_reg: 0.2405 (0.2353)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0028 (0.0028)	loss_sum: 0.3383 (0.3382)	time: 0.6127	data: 0.0012	max mem: 5903
# Train: [5]	[22/60]	eta: 0:00:23	loss_classifier: 0.0876 (0.0953)	loss_box_reg: 0.2273 (0.2341)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0027 (0.0028)	loss_sum: 0.3298 (0.3362)	time: 0.6123	data: 0.0012	max mem: 5903
# Train: [5]	[23/60]	eta: 0:00:23	loss_classifier: 0.0876 (0.0959)	loss_box_reg: 0.2273 (0.2337)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0027 (0.0028)	loss_sum: 0.3298 (0.3364)	time: 0.6162	data: 0.0012	max mem: 5903
# Train: [5]	[24/60]	eta: 0:00:22	loss_classifier: 0.0876 (0.0959)	loss_box_reg: 0.2273 (0.2350)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0025 (0.0028)	loss_sum: 0.3298 (0.3377)	time: 0.6216	data: 0.0012	max mem: 5903
# Train: [5]	[25/60]	eta: 0:00:22	loss_classifier: 0.0876 (0.0968)	loss_box_reg: 0.2273 (0.2365)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0027 (0.0028)	loss_sum: 0.3298 (0.3402)	time: 0.6221	data: 0.0012	max mem: 5903
# Train: [5]	[26/60]	eta: 0:00:21	loss_classifier: 0.0905 (0.0971)	loss_box_reg: 0.2405 (0.2370)	loss_objectness: 0.0038 (0.0040)	loss_rpn_box_reg: 0.0027 (0.0028)	loss_sum: 0.3383 (0.3410)	time: 0.6227	data: 0.0012	max mem: 5903
# Train: [5]	[27/60]	eta: 0:00:21	loss_classifier: 0.0957 (0.0973)	loss_box_reg: 0.2426 (0.2373)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3406 (0.3417)	time: 0.6244	data: 0.0012	max mem: 5903
# Train: [5]	[28/60]	eta: 0:00:20	loss_classifier: 0.0905 (0.0969)	loss_box_reg: 0.2426 (0.2352)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3406 (0.3391)	time: 0.6252	data: 0.0012	max mem: 5903
# Train: [5]	[29/60]	eta: 0:00:19	loss_classifier: 0.0905 (0.0969)	loss_box_reg: 0.2405 (0.2339)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3383 (0.3379)	time: 0.6246	data: 0.0012	max mem: 5903
# Train: [5]	[30/60]	eta: 0:00:19	loss_classifier: 0.0957 (0.0971)	loss_box_reg: 0.2429 (0.2352)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3406 (0.3394)	time: 0.6248	data: 0.0012	max mem: 5903
# Train: [5]	[31/60]	eta: 0:00:18	loss_classifier: 0.0957 (0.0967)	loss_box_reg: 0.2458 (0.2356)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3409 (0.3394)	time: 0.6243	data: 0.0012	max mem: 5903
# Train: [5]	[32/60]	eta: 0:00:17	loss_classifier: 0.0979 (0.0968)	loss_box_reg: 0.2458 (0.2355)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3409 (0.3393)	time: 0.6239	data: 0.0012	max mem: 5903
# Train: [5]	[33/60]	eta: 0:00:17	loss_classifier: 0.0979 (0.0971)	loss_box_reg: 0.2405 (0.2354)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3409 (0.3396)	time: 0.6284	data: 0.0013	max mem: 5903
# Train: [5]	[34/60]	eta: 0:00:16	loss_classifier: 0.0957 (0.0966)	loss_box_reg: 0.2359 (0.2354)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3406 (0.3391)	time: 0.6281	data: 0.0013	max mem: 5903
# Train: [5]	[35/60]	eta: 0:00:16	loss_classifier: 0.0957 (0.0966)	loss_box_reg: 0.2359 (0.2357)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3406 (0.3394)	time: 0.6310	data: 0.0013	max mem: 5903
# Train: [5]	[36/60]	eta: 0:00:15	loss_classifier: 0.0957 (0.0962)	loss_box_reg: 0.2359 (0.2344)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3406 (0.3377)	time: 0.6325	data: 0.0013	max mem: 5903
# Train: [5]	[37/60]	eta: 0:00:14	loss_classifier: 0.0957 (0.0982)	loss_box_reg: 0.2359 (0.2382)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3406 (0.3435)	time: 0.6329	data: 0.0013	max mem: 5903
# Train: [5]	[38/60]	eta: 0:00:14	loss_classifier: 0.0957 (0.0979)	loss_box_reg: 0.2359 (0.2369)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3406 (0.3419)	time: 0.6334	data: 0.0013	max mem: 5903
# Train: [5]	[39/60]	eta: 0:00:13	loss_classifier: 0.0957 (0.0986)	loss_box_reg: 0.2359 (0.2381)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3406 (0.3438)	time: 0.6353	data: 0.0013	max mem: 5903
# Train: [5]	[40/60]	eta: 0:00:13	loss_classifier: 0.0957 (0.0984)	loss_box_reg: 0.2359 (0.2369)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3406 (0.3425)	time: 0.6331	data: 0.0013	max mem: 5903
# Train: [5]	[41/60]	eta: 0:00:12	loss_classifier: 0.0979 (0.0993)	loss_box_reg: 0.2359 (0.2396)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3409 (0.3460)	time: 0.6346	data: 0.0012	max mem: 5903
# Train: [5]	[42/60]	eta: 0:00:11	loss_classifier: 0.0985 (0.0995)	loss_box_reg: 0.2359 (0.2388)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0031 (0.0030)	loss_sum: 0.3409 (0.3454)	time: 0.6356	data: 0.0012	max mem: 5903
# Train: [5]	[43/60]	eta: 0:00:11	loss_classifier: 0.0979 (0.0992)	loss_box_reg: 0.2396 (0.2388)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3409 (0.3451)	time: 0.6362	data: 0.0013	max mem: 5903
# Train: [5]	[44/60]	eta: 0:00:10	loss_classifier: 0.0985 (0.0993)	loss_box_reg: 0.2396 (0.2390)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3409 (0.3453)	time: 0.6334	data: 0.0013	max mem: 5903
# Train: [5]	[45/60]	eta: 0:00:10	loss_classifier: 0.0979 (0.0992)	loss_box_reg: 0.2359 (0.2384)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0029 (0.0030)	loss_sum: 0.3363 (0.3447)	time: 0.6331	data: 0.0013	max mem: 5903
# Train: [5]	[46/60]	eta: 0:00:09	loss_classifier: 0.0947 (0.0989)	loss_box_reg: 0.2330 (0.2383)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0029)	loss_sum: 0.3323 (0.3443)	time: 0.6391	data: 0.0013	max mem: 5903
# Train: [5]	[47/60]	eta: 0:00:08	loss_classifier: 0.0945 (0.0988)	loss_box_reg: 0.2319 (0.2373)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0028 (0.0030)	loss_sum: 0.3278 (0.3433)	time: 0.6406	data: 0.0014	max mem: 5903
# Train: [5]	[48/60]	eta: 0:00:08	loss_classifier: 0.0945 (0.0981)	loss_box_reg: 0.2319 (0.2363)	loss_objectness: 0.0035 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3278 (0.3415)	time: 0.6391	data: 0.0014	max mem: 5903
# Train: [5]	[49/60]	eta: 0:00:07	loss_classifier: 0.0945 (0.0981)	loss_box_reg: 0.2319 (0.2359)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3278 (0.3412)	time: 0.6420	data: 0.0014	max mem: 5903
# Train: [5]	[50/60]	eta: 0:00:06	loss_classifier: 0.0933 (0.0980)	loss_box_reg: 0.2319 (0.2350)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3264 (0.3401)	time: 0.6428	data: 0.0014	max mem: 5903
# Train: [5]	[51/60]	eta: 0:00:06	loss_classifier: 0.0945 (0.0980)	loss_box_reg: 0.2319 (0.2355)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3264 (0.3405)	time: 0.6457	data: 0.0015	max mem: 5903
# Train: [5]	[52/60]	eta: 0:00:05	loss_classifier: 0.0945 (0.0983)	loss_box_reg: 0.2319 (0.2358)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3264 (0.3412)	time: 0.6479	data: 0.0015	max mem: 5903
# Train: [5]	[53/60]	eta: 0:00:05	loss_classifier: 0.0945 (0.0984)	loss_box_reg: 0.2330 (0.2368)	loss_objectness: 0.0037 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3264 (0.3423)	time: 0.6437	data: 0.0015	max mem: 5903
# Train: [5]	[54/60]	eta: 0:00:04	loss_classifier: 0.0945 (0.0983)	loss_box_reg: 0.2330 (0.2368)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3278 (0.3423)	time: 0.6433	data: 0.0015	max mem: 5903
# Train: [5]	[55/60]	eta: 0:00:03	loss_classifier: 0.0933 (0.0982)	loss_box_reg: 0.2330 (0.2371)	loss_objectness: 0.0037 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0029)	loss_sum: 0.3278 (0.3424)	time: 0.6403	data: 0.0015	max mem: 5903
# Train: [5]	[56/60]	eta: 0:00:03	loss_classifier: 0.0945 (0.0990)	loss_box_reg: 0.2383 (0.2397)	loss_objectness: 0.0038 (0.0041)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3323 (0.3458)	time: 0.6444	data: 0.0015	max mem: 5903
# Train: [5]	[57/60]	eta: 0:00:02	loss_classifier: 0.0945 (0.0997)	loss_box_reg: 0.2383 (0.2406)	loss_objectness: 0.0038 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3323 (0.3475)	time: 0.6475	data: 0.0015	max mem: 5903
# Train: [5]	[58/60]	eta: 0:00:01	loss_classifier: 0.0973 (0.1000)	loss_box_reg: 0.2396 (0.2415)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0027 (0.0030)	loss_sum: 0.3388 (0.3486)	time: 0.6474	data: 0.0015	max mem: 5903
# Train: [5]	[59/60]	eta: 0:00:01	loss_classifier: 0.0945 (0.0998)	loss_box_reg: 0.2396 (0.2418)	loss_objectness: 0.0041 (0.0042)	loss_rpn_box_reg: 0.0026 (0.0030)	loss_sum: 0.3388 (0.3487)	time: 0.6452	data: 0.0015	max mem: 5903
# Train: [5]	[60/60]	eta: 0:00:00	loss_classifier: 0.0973 (0.0998)	loss_box_reg: 0.2396 (0.2416)	loss_objectness: 0.0037 (0.0042)	loss_rpn_box_reg: 0.0025 (0.0030)	loss_sum: 0.3388 (0.3485)	time: 0.6304	data: 0.0015	max mem: 5903
# Train: [5] Total time: 0:00:37 (0.6262s / iteration)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Test: [5]	[1/8]	eta: 0:00:02	model_time: 0.3378 (0.3378)	evaluator_time: 0.0266 (0.0266)	time: 0.3743	data: 0.0010	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Test: [5]	[2/8]	eta: 0:00:02	model_time: 0.3378 (0.3441)	evaluator_time: 0.0231 (0.0249)	time: 0.3792	data: 0.0012	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [5]	[3/8]	eta: 0:00:02	model_time: 0.3378 (0.3396)	evaluator_time: 0.0231 (0.0218)	time: 0.3720	data: 0.0013	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [5]	[4/8]	eta: 0:00:01	model_time: 0.3373 (0.3390)	evaluator_time: 0.0173 (0.0207)	time: 0.3698	data: 0.0012	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [5]	[5/8]	eta: 0:00:01	model_time: 0.3378 (0.3404)	evaluator_time: 0.0173 (0.0195)	time: 0.3698	data: 0.0012	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [5]	[6/8]	eta: 0:00:01	model_time: 0.3373 (0.3396)	evaluator_time: 0.0158 (0.0183)	time: 0.3676	data: 0.0012	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Test: [5]	[7/8]	eta: 0:00:00	model_time: 0.3373 (0.3392)	evaluator_time: 0.0158 (0.0174)	time: 0.3661	data: 0.0011	max mem: 5903
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.00s).
# Test: [5]	[8/8]	eta: 0:00:00	model_time: 0.3365 (0.3156)	evaluator_time: 0.0148 (0.0161)	time: 0.3404	data: 0.0010	max mem: 5903
# Test: [5] Total time: 0:00:02 (0.3407s / iteration)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.618
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.842
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.667
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# Finished Training

# %%
now = datetime.datetime.now().strftime("%Y%m%d_%H:%M:%S")
model_weights = f"../../../pretrained-models/fasterrcnn-scale{hyp.scale}-bs{hyp.batch_size}-epochs{hyp.num_epochs}-weights-{now}.pth"
print(model_weights)
# torch.save(model.state_dict(), model_weights)
# Out:
# ../../../pretrained-models/fasterrcnn-scale0.1-bs32-epochs2-weights-20240306_12:07:06.pth

# %%
import os
output_dir_now = os.path.join("../../outputs/", now)
os.makedirs(output_dir_now, exist_ok=True)

# %%
writer.flush()
writer.close()

import shutil
shutil.rmtree(log_dir)

# %%
import matplotlib.pyplot as plt
from torchvision.utils import draw_bounding_boxes

# %%
images_batch, targets_batch = next(iter(dataloaders["test"]))
images = [image for image in images_batch]
targets = [{k: v for k, v in t.items()} for t in targets_batch]

# %%
img = images[0]
img_int = torch.tensor(img*255, dtype=torch.uint8)
with torch.no_grad():
    prediction = model([img.to(device)])
    pred = prediction[0]

# %%
print(f"Boxes:\n\t{pred['boxes']}\nScores:\n\t{pred['scores']}")

# %%
figure = plt.figure(figsize=(14, 8*32))
cols, rows = 2, 32


for i, img in enumerate(images):
    img_int = torch.tensor(img*255, dtype=torch.uint8)
    with torch.no_grad():
        prediction = model([img.to(device)])
        pred = prediction[0]
    figure.add_subplot(rows, cols, i*2+1)
    plt.imshow(
        draw_bounding_boxes(
            image=img_int,
            boxes=pred['boxes'],
            colors=["red"]*len(pred['boxes']),
            width=1
    ).permute(1, 2, 0))
    
    figure.add_subplot(rows, cols, i*2+2)
    plt.imshow(
        draw_bounding_boxes(
            image=img_int,
            boxes=targets[i]["boxes"],
            colors=["blue"]*len(targets[i]['boxes']),
            width=1
    ).permute(1, 2, 0))
plt.show()
